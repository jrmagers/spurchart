# %% [markdown]
# # Mixer Examples

# %%
import pathlib

from spurchart.mixer import transmit, receive
from spurchart.mixer.swept import NormalLog

# assets = pathlib.Path.cwd().parent / "docs" / 'assets'

# %%
NormalLog(order=(3,3))
NormalLog(order=(3,3))
# Out:
# NormalLog(order=(3, 3), lo_power=20)
