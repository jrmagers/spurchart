# %% [markdown]
# # Mixer Examples

# %%
import pathlib

from spurchart.mixer import transmit, receive
from spurchart.mixer.swept import NormalLogNew

# assets = pathlib.Path.cwd().parent / "docs" / 'assets'

# %%
rx = NormalLogNew(order=(3,3),fif=30,bw=4)
rx.ax.set_xlim(1,10)
rx.ax.set_ylim(1,10)
# Out:
# (1.0, 10.0)
